# %%
import os

input_dir = "C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/"
target_dir = "C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/"
img_size = (1024, 1024)
num_classes = 2
batch_size = 32

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".jpg") and not fname.startswith(".")
    ]
)

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:10], target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 2451
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34052.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34052.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34053.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34053.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34054.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34054.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34055.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34055.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34056.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34056.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34057.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34057.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34058.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34058.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34059.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34059.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34060.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34060.jpg
# C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/images/34061.jpg | C:/Users/itsde/OneDrive/git_repos/Object-Detection-and-Tracking/Trapping/masks/34061.jpg

# %%
from IPython.display import Image, display
from keras.utils import load_img
from PIL import ImageOps

# Display input image #7
display(Image(filename=input_img_paths[9]))

# Display auto-contrast version of corresponding target (per-pixel categories)
img = ImageOps.autocontrast(load_img(target_img_paths[9]))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
import keras
import numpy as np
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io


def get_dataset(
    batch_size,
    img_size,
    input_img_paths,
    target_img_paths,
    max_dataset_len=None,
):
    """Returns a TF Dataset."""

    def load_img_masks(input_img_path, target_img_path):
        input_img = tf_io.read_file(input_img_path)
        input_img = tf_io.decode_png(input_img, channels=3)
        #input_img = tf_image.resize(input_img, img_size)
        input_img = tf_image.convert_image_dtype(input_img, "float32")

        target_img = tf_io.read_file(target_img_path)
        target_img = tf_io.decode_png(target_img, channels=1)
        #target_img = tf_image.resize(target_img, img_size, method="nearest")
        target_img = tf_image.convert_image_dtype(target_img, "uint8")

        # Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
        #target_img -= 1
        return input_img, target_img

    # For faster debugging, limit the size of data
    if max_dataset_len:
        input_img_paths = input_img_paths[:max_dataset_len]
        target_img_paths = target_img_paths[:max_dataset_len]
    dataset = tf_data.Dataset.from_tensor_slices((input_img_paths, target_img_paths))
    dataset = dataset.map(load_img_masks, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.batch(batch_size)

# %%
from keras import layers


def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1024, 1024,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 512, 512, 32  0           ['activation[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 512, 512, 64  2400       ['activation_1[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 512, 512, 64  4736       ['activation_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 64  256        ['separable_conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  2112        ['activation[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  activation_3 (Activation)      (None, 256, 256, 64  0           ['add[0][0]']
#                                 )
#
#  separable_conv2d_2 (SeparableC  (None, 256, 256, 12  8896       ['activation_3[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['separable_conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  separable_conv2d_3 (SeparableC  (None, 256, 256, 12  17664      ['activation_4[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 12  512        ['separable_conv2d_3[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  8320        ['add[0][0]']
#                                 8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['max_pooling2d_1[0][0]',
#                                 8)                                'conv2d_2[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['add_1[0][0]']
#                                 8)
#
#  separable_conv2d_4 (SeparableC  (None, 128, 128, 25  34176      ['activation_5[0][0]']
#  onv2D)                         6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['separable_conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_6 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  separable_conv2d_5 (SeparableC  (None, 128, 128, 25  68096      ['activation_6[0][0]']
#  onv2D)                         6)
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 25  1024       ['separable_conv2d_5[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['batch_normalization_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  33024       ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 256)  0           ['add_2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  590080     ['activation_7[0][0]']
#  ose)
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  590080     ['activation_8[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['add_2[0][0]']
#                                 6)
#
#  up_sampling2d (UpSampling2D)   (None, 128, 128, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  65792       ['up_sampling2d_1[0][0]']
#                                 6)
#
#  add_3 (Add)                    (None, 128, 128, 25  0           ['up_sampling2d[0][0]',
#                                 6)                                'conv2d_4[0][0]']
#
#  activation_9 (Activation)      (None, 128, 128, 25  0           ['add_3[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  295040     ['activation_9[0][0]']
#  spose)                         8)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 12  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   8)
#
#  activation_10 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_9[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 12  147584     ['activation_10[0][0]']
#  spose)                         8)
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 12  512        ['conv2d_transpose_3[0][0]']
#  ormalization)                  8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 25  0          ['add_3[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 12  0          ['batch_normalization_10[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  32896       ['up_sampling2d_3[0][0]']
#                                 8)
#
#  add_4 (Add)                    (None, 256, 256, 12  0           ['up_sampling2d_2[0][0]',
#                                 8)                                'conv2d_5[0][0]']
#
#  activation_11 (Activation)     (None, 256, 256, 12  0           ['add_4[0][0]']
#                                 8)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 256, 256, 64  73792      ['activation_11[0][0]']
#  spose)                         )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 64  256        ['conv2d_transpose_4[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 256, 256, 64  36928      ['activation_12[0][0]']
#  spose)                         )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 64  256        ['conv2d_transpose_5[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 512, 512, 12  0          ['add_4[0][0]']
#                                 8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 64  0          ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  8256        ['up_sampling2d_5[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 512, 512, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_6[0][0]']
#
#  activation_13 (Activation)     (None, 512, 512, 64  0           ['add_5[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 512, 512, 32  18464      ['activation_13[0][0]']
#  spose)                         )
#
#  batch_normalization_13 (BatchN  (None, 512, 512, 32  128        ['conv2d_transpose_6[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 512, 512, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 32  9248       ['activation_14[0][0]']
#  spose)                         )
#
#  batch_normalization_14 (BatchN  (None, 512, 512, 32  128        ['conv2d_transpose_7[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 1024, 1024,   0          ['add_5[0][0]']
#                                 64)
#
#  up_sampling2d_6 (UpSampling2D)  (None, 1024, 1024,   0          ['batch_normalization_14[0][0]']
#                                 32)
#
#  conv2d_7 (Conv2D)              (None, 1024, 1024,   2080        ['up_sampling2d_7[0][0]']
#                                 32)
#
#  add_6 (Add)                    (None, 1024, 1024,   0           ['up_sampling2d_6[0][0]',
#                                 32)                               'conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 1024, 1024,   578         ['add_6[0][0]']
#                                 2)
#
# ==================================================================================================
# Total params: 2,058,690
# Trainable params: 2,054,914
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %%
import random

# Split our img paths into a training and a validation set
val_samples = 1000
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

# Instantiate dataset for each split
# Limit input files in `max_dataset_len` for faster epoch training time.
# Remove the `max_dataset_len` arg when running with full dataset.
train_dataset = get_dataset(
    batch_size,
    img_size,
    train_input_img_paths,
    train_target_img_paths,
    max_dataset_len=1000,
)
valid_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)

# %%
# Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
model.compile(
    optimizer=keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy"
)

callbacks = [
    keras.callbacks.ModelCheckpoint("Semantic_Segmentation_PS.keras", save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
epochs = 50
model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Epoch 1/50
